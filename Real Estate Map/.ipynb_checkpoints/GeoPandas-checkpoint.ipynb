# %%
# pip install geopandas

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
# Importing real estate data
df = pd.read_csv('./CSVs/coord_no_zeros.csv')

# %%
df.head()
# Out:
#   Baths Beds                                           Location Square Meter  \
# 0     2    2                   Baymount, Al Ain Al Sokhna, Suez          105
# 1     2    2            Aroma Residence, Al Ain Al Sokhna, Suez           95
# 2     4    5  Mivida, 5th Settlement Compounds, The 5th Sett...          391
# 3     2    3            IL Monte Galala, Al Ain Al Sokhna, Suez          119
# 4     2    2  Century City, 5th Settlement Compounds, The 5t...          100
#
#    base_price    city country page    price_usd property_type  \
# 0     1200000    Suez   Egypt  buy   18876000.0        Chalet
# 1     1550000    Suez   Egypt  buy   24381500.0        Chalet
# 2     8400000   Cairo   Egypt  buy  132132000.0         Villa
# 3     2900000    Suez   Egypt  buy   45617000.0        Chalet
# 4     1425000   Cairo   Egypt  buy   22415250.0     Apartment
#
#              sub_div  Longitude   Latitude
# 0   Al Ain Al Sokhna  30.074282  31.544374
# 1   Al Ain Al Sokhna  30.074282  31.544374
# 2     New Cairo City  30.063103  31.455447
# 3   Al Ain Al Sokhna  30.074282  31.544374
# 4     New Cairo City  30.063103  31.455447

# %%
# Checking the length
df.shape
# Out:
# (4966, 13)

# %%
# Checking the min and max lat and lon
df[['Longitude', 'Latitude']].describe()
# Out:
#          Longitude     Latitude
# count  4966.000000  4966.000000
# mean     30.046973    31.404273
# std       0.036381     0.100907
# min      29.550000    31.133333
# 25%      30.020128    31.296087
# 50%      30.052118    31.455447
# 75%      30.063103    31.455447
# max      30.290010    31.760475

# %%
# Setting a point with the lon and lat coordinates with GeoPandas
geometry = [Point(xy) for xy in zip(df['Latitude'], df['Longitude'])]
crs = {'init' :'epsg:4326'}

geo = gpd.GeoDataFrame(df, crs = crs, geometry = geometry)

geo.head()
# Out:
#   Baths Beds                                           Location Square Meter  \
# 0     2    2                   Baymount, Al Ain Al Sokhna, Suez          105
# 1     2    2            Aroma Residence, Al Ain Al Sokhna, Suez           95
# 2     4    5  Mivida, 5th Settlement Compounds, The 5th Sett...          391
# 3     2    3            IL Monte Galala, Al Ain Al Sokhna, Suez          119
# 4     2    2  Century City, 5th Settlement Compounds, The 5t...          100
#
#    base_price    city country page    price_usd property_type  \
# 0     1200000    Suez   Egypt  buy   18876000.0        Chalet
# 1     1550000    Suez   Egypt  buy   24381500.0        Chalet
# 2     8400000   Cairo   Egypt  buy  132132000.0         Villa
# 3     2900000    Suez   Egypt  buy   45617000.0        Chalet
# 4     1425000   Cairo   Egypt  buy   22415250.0     Apartment
#
#              sub_div  Longitude   Latitude                   geometry
# 0   Al Ain Al Sokhna  30.074282  31.544374  POINT (31.54437 30.07428)
# 1   Al Ain Al Sokhna  30.074282  31.544374  POINT (31.54437 30.07428)
# 2     New Cairo City  30.063103  31.455447  POINT (31.45545 30.06310)
# 3   Al Ain Al Sokhna  30.074282  31.544374  POINT (31.54437 30.07428)
# 4     New Cairo City  30.063103  31.455447  POINT (31.45545 30.06310)

# %%
geo.tail()
# Out:
#      Baths Beds                                           Location  \
# 4961     3  NaN  90 Street, The 5th Settlement, New Cairo City,...
# 4962     1  NaN  North Teseen St., The 5th Settlement, New Cair...
# 4963     1  NaN  North Teseen St., The 5th Settlement, New Cair...
# 4964     3  NaN                           Mosadak St., Dokki, Giza
# 4965   NaN  NaN  Bank Center Street, South Teseen St., The 5th ...
#
#      Square Meter  base_price    city country        page  price_usd  \
# 4961          160       35000   Cairo   Egypt  commercial   550550.0
# 4962           50       11000   Cairo   Egypt  commercial   173030.0
# 4963           55       13000   Cairo   Egypt  commercial   204490.0
# 4964          120       20000    Giza   Egypt  commercial   314600.0
# 4965          570      200000   Cairo   Egypt  commercial  3146000.0
#
#          property_type          sub_div  Longitude   Latitude  \
# 4961      Office Space   New Cairo City  30.020128  31.498221
# 4962  Medical Facility   New Cairo City  30.020128  31.498221
# 4963  Medical Facility   New Cairo City  30.020128  31.498221
# 4964  Medical Facility            Dokki  30.017004  31.213451
# 4965            Retail   New Cairo City  30.063103  31.455447
#
#                        geometry
# 4961  POINT (31.49822 30.02013)
# 4962  POINT (31.49822 30.02013)
# 4963  POINT (31.49822 30.02013)
# 4964  POINT (31.21345 30.01700)
# 4965  POINT (31.45545 30.06310)

# %%
# Reading the geomap dataframe to a csv
geo.to_csv('./CSVs/geomap.csv', index = False)

# %%
# checking the base_price
df['base_price'].describe()
# Out:
# count    4.966000e+03
# mean     2.890657e+06
# std      3.084465e+07
# min      1.000000e+03
# 25%      2.700000e+04
# 50%      9.600000e+04
# 75%      2.618500e+06
# max      2.125000e+09
# Name: base_price, dtype: float64

# %%
# NEED SHAPE FILE OF CAIRO
cairo_map = gpd.read_file('../egypt_highway/egypt_highway.shp')

# %%
# Plotting the geomap dataframe
fig,ax = plt.subplots(figsize = (15,15))
#cairo_map.plot(ax = ax, color = 'blue', alpha = 0.10)
geo[geo['base_price'] == 1].plot(ax = ax, marker = "*", markersize = 250, color = 'red');
geo[(geo['base_price'] > 1) & (geo['base_price'] <= 2.500000e+04)].plot(ax = ax, marker = "+", markersize = 200, color = 'orange')
geo[geo['base_price'] > 2.600000e+06].plot(ax = ax, marker = "^", color = 'skyblue');
# Out:
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/geopandas/plotting.py:510: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
